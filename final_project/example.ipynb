# %% [markdown]
# # 기말 프로젝트

# %% [markdown]
# ## 주제 기획안

# %% [markdown]
# ### 1. 실시간 가위바위보
# > Kaggle에는 'Rock, Paper, Siccors Images' 데이터셋이 있다. <br> 이를 사용해 모델을 학습시켜 나를 반드시 이기는 가위바위보 모델을 만들 수 있지 않을까? <br> 예를 들어 내가 가위를 내기 직전에 모델이 가위라 예측한다면 즉시 주먹을 내서 나를 반드시 이긴다.

# %% [markdown]
# ## 2. 기계 음성에 감정 입히기
# > 음성과 여러 감정들이 연결된 데이터가 존재 (RAVDESS (Ryerson Audio-Visual Database of Emotional Speech and Song))<br>이를 사용해 모델을 학습시킨 후 생성모델(오토인코더) 생성
# <br> 이를 통해 기계어에 음성을 입힐 수 있지 않을까...
